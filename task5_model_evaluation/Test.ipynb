# %%
# %pip install llama-index-llms-huggingface
# %pip install llama-index-llms-huggingface-api
# !pip install "transformers[torch]" "huggingface_hub[inference]"
# !pip install llama-index
# Out:
# Collecting llama-index-llms-huggingface
#   Downloading llama_index_llms_huggingface-0.3.1-py3-none-any.whl.metadata (789 bytes)
# Collecting huggingface-hub<0.24.0,>=0.23.0 (from llama-index-llms-huggingface)
#   Downloading huggingface_hub-0.23.5-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-llms-huggingface) (0.11.0.post1)
# Collecting text-generation<0.8.0,>=0.7.0 (from llama-index-llms-huggingface)
#   Downloading text_generation-0.7.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: torch<3.0.0,>=2.1.2 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-llms-huggingface) (2.4.0)
# Requirement already satisfied: transformers<5.0.0,>=4.37.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (4.44.0)
# Requirement already satisfied: filelock in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (6.0.2)
# Requirement already satisfied: requests in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (4.12.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.10.4)
# Requirement already satisfied: dataclasses-json in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.0.8)
# Requirement already satisfied: httpx in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.23.3)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.16.0)
# Requirement already satisfied: sympy in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.13.1)
# Requirement already satisfied: jinja2 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (3.1.4)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (2024.7.24)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.4.4)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from transformers<5.0.0,>=4.37.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (0.19.1)
# Collecting accelerate>=0.21.0 (from transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface)
#   Downloading accelerate-0.33.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: psutil in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from accelerate>=0.21.0->transformers[torch]<5.0.0,>=4.37.0->llama-index-llms-huggingface) (6.0.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (2.3.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.9.4)
# Requirement already satisfied: click in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (8.1.7)
# Requirement already satisfied: joblib in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.4.2)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.0.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.0.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.0.3)
# Requirement already satisfied: colorama in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.42.1->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (3.21.3)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.16.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.5.0)
# Requirement already satisfied: sniffio in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from jinja2->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from sympy->torch<3.0.0,>=2.1.2->llama-index-llms-huggingface) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface) (4.4.0)
# Downloading llama_index_llms_huggingface-0.3.1-py3-none-any.whl (11 kB)
# Downloading huggingface_hub-0.23.5-py3-none-any.whl (402 kB)
# Downloading text_generation-0.7.0-py3-none-any.whl (12 kB)
# Downloading accelerate-0.33.0-py3-none-any.whl (315 kB)
# Installing collected packages: huggingface-hub, text-generation, accelerate, llama-index-llms-huggingface
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.24.5
#     Uninstalling huggingface-hub-0.24.5:
#       Successfully uninstalled huggingface-hub-0.24.5
# Successfully installed accelerate-0.33.0 huggingface-hub-0.23.5 llama-index-llms-huggingface-0.3.1 text-generation-0.7.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting llama-index-llms-huggingface-api
#   Downloading llama_index_llms_huggingface_api-0.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: huggingface-hub<0.24.0,>=0.23.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-llms-huggingface-api) (0.23.5)
# Requirement already satisfied: llama-index-core<0.12.0,>=0.11.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-llms-huggingface-api) (0.11.0.post1)
# Requirement already satisfied: filelock in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (3.15.4)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (2024.6.1)
# Requirement already satisfied: packaging>=20.9 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (6.0.2)
# Requirement already satisfied: requests in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (2.32.3)
# Requirement already satisfied: tqdm>=4.42.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (4.66.5)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (4.12.2)
# Requirement already satisfied: SQLAlchemy>=1.4.49 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (2.0.32)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.6 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (3.10.4)
# Requirement already satisfied: dataclasses-json in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (0.6.7)
# Requirement already satisfied: deprecated>=1.2.9.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.2.14)
# Requirement already satisfied: dirtyjson<2.0.0,>=1.0.8 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.0.8)
# Requirement already satisfied: httpx in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (0.23.3)
# Requirement already satisfied: nest-asyncio<2.0.0,>=1.5.8 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.6.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (3.3)
# Requirement already satisfied: nltk>3.8.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (3.9.1)
# Requirement already satisfied: numpy<2.0.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.26.4)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (10.4.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.0.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.2.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (8.2.3)
# Requirement already satisfied: tiktoken>=0.3.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (0.7.0)
# Requirement already satisfied: typing-inspect>=0.8.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (0.9.0)
# Requirement already satisfied: wrapt in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.16.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (2.3.7)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (24.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from aiohttp<4.0.0,>=3.8.6->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.9.4)
# Requirement already satisfied: click in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (8.1.7)
# Requirement already satisfied: joblib in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from nltk>3.8.1->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (2024.7.24)
# Requirement already satisfied: annotated-types>=0.4.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.0.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from pydantic<3.0.0,>=2.0.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (2024.7.4)
# Requirement already satisfied: greenlet!=0.4.17 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from SQLAlchemy>=1.4.49->SQLAlchemy[asyncio]>=1.4.49->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (3.0.3)
# Requirement already satisfied: colorama in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from tqdm>=4.42.1->huggingface-hub<0.24.0,>=0.23.0->llama-index-llms-huggingface-api) (0.4.6)
# Requirement already satisfied: mypy-extensions>=0.3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from typing-inspect>=0.8.0->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.0.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from dataclasses-json->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (3.21.3)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (0.16.3)
# Requirement already satisfied: rfc3986<2,>=1.3 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from rfc3986[idna2008]<2,>=1.3->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.5.0)
# Requirement already satisfied: sniffio in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (1.3.1)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (0.14.0)
# Requirement already satisfied: anyio<5.0,>=3.0 in c:\users\agshi\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from httpcore<0.17.0,>=0.15.0->httpx->llama-index-core<0.12.0,>=0.11.0->llama-index-llms-huggingface-api) (4.4.0)
# Downloading llama_index_llms_huggingface_api-0.2.0-py3-none-any.whl (5.0 kB)
# Installing collected packages: llama-index-llms-huggingface-api
# Successfully installed llama-index-llms-huggingface-api-0.2.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from typing import List, Optional

#from llama_index.llms.huggingface import HuggingFaceLLM
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI

# SEE: https://huggingface.co/docs/hub/security-tokens
# We just need a token with read permissions for this demo
# NOTE: None default will fall back on Hugging Face's token storage
# when this token gets used within HuggingFaceInferenceAPI
# Out:
# C:\Users\agshi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pydantic\_internal\_fields.py:161: UserWarning: Field "model_name" has conflict with protected namespace "model_".
#
# You may be able to resolve this warning by setting `model_config['protected_namespaces'] = ()`.
#   warnings.warn(

# %%
remotely_run = HuggingFaceInferenceAPI(
    model_name="HuggingFaceH4/zephyr-7b-alpha", token=HF_TOKEN
)

# %%
completion_response = remotely_run.complete("To infinity, and")
print(completion_response)
# Out:
#  beyond!
#
# The Toy Story franchise has been a beloved part of pop culture for over two decades, and it's not slowing down anytime soon. The latest installment, Toy Story 4, is set to hit theaters this summer, and it's already generating buzz.
#
# The movie follows the adventures of Woody, Buzz, and the gang as they embark on a new adventure with a new toy, Forky. The trailer for the movie has been released, and it's already getting fans excited for the film.
#
# One of the most exciting things about Toy Story 4 is the return of some beloved characters. Bo Peep, who was last seen in Toy Story 2, is back and looking better than ever. She's now a modern, independent woman, and her new look has been getting a lot of attention.
#
# Another exciting addition to the movie is the introduction of new characters, including Forky, who is voiced by Tony Hale. Forky is a spork with a popsicle stick for a handle, and he's not exactly thrilled about being a toy.
#
# The trailer for Toy Story 4 has been viewed over 10 million

# %%
from pinecone import Pinecone, ServerlessSpec

# Set up Pinecone connection
pc = Pinecone(

index = pc.Index("test-index")

# %%
# initialize without metadata filter
from llama_index.core import VectorStoreIndex, SimpleDirectoryReader
from llama_index.vector_stores.pinecone import PineconeVectorStore
from IPython.display import Markdown, display
from llama_index.core import StorageContext



vector_store = PineconeVectorStore(pinecone_index=index)
storage_context = StorageContext.from_defaults(vector_store=vector_store)

# load documents
documents = SimpleDirectoryReader(r"C:\Users\agshi\Desktop\Omdena\Canada Policy\TorontoCanadaChapter_CanPolicyInsight\task5_model_evaluation").load_data()

# %%
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.core import Settings

Settings.embed_model = HuggingFaceEmbedding(
    model_name="HuggingFaceH4/zephyr-7b-alpha",token=HF_TOKEN)
# Out:
# No sentence-transformers model found with name HuggingFaceH4/zephyr-7b-alpha. Creating a new one with mean pooling.
# C:\Users\agshi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:157: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\agshi\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\Local\llama_index\models--HuggingFaceH4--zephyr-7b-alpha. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# Downloading shards:  38%|███▊      | 3/8 [02:56<04:54, 58.91s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 from llama_index.embeddings.huggingface import HuggingFaceEmbedding
#       2 from llama_index.core import Settings
# ----> 4 Settings.embed_model = HuggingFaceEmbedding(
#       5     model_name="HuggingFaceH4/zephyr-7b-alpha",token=HF_TOKEN)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\llama_index\embeddings\huggingface\base.py:150, in HuggingFaceEmbedding.__init__(self, model_name, tokenizer_name, pooling, max_length, query_instruction, text_instruction, normalize, model, tokenizer, embed_batch_size, cache_folder, trust_remote_code, device, callback_manager, parallel_process, target_devices, **model_kwargs)
#     147 if model_name is None:
#     148     raise ValueError("The `model_name` argument must be provided.")
# --> 150 model = SentenceTransformer(
#     151     model_name,
#     152     device=device,
#     153     cache_folder=cache_folder,
#     154     trust_remote_code=trust_remote_code,
#     155     prompts={
#     156         "query": query_instruction
#     157         or get_query_instruct_for_model_name(model_name),
#     158         "text": text_instruction
#     159         or get_text_instruct_for_model_name(model_name),
#     160     },
#     161     **model_kwargs,
#     162 )
#     163 if max_length:
#     164     model.max_seq_length = max_length
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sentence_transformers\SentenceTransformer.py:299, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data)
#     287         modules = self._load_sbert_model(
#     288             model_name_or_path,
#     289             token=token,
#    (...)
#     296             config_kwargs=config_kwargs,
#     297         )
#     298     else:
# --> 299         modules = self._load_auto_model(
#     300             model_name_or_path,
#     301             token=token,
#     302             cache_folder=cache_folder,
#     303             revision=revision,
#     304             trust_remote_code=trust_remote_code,
#     305             local_files_only=local_files_only,
#     306             model_kwargs=model_kwargs,
#     307             tokenizer_kwargs=tokenizer_kwargs,
#     308             config_kwargs=config_kwargs,
#     309         )
#     311 if modules is not None and not isinstance(modules, OrderedDict):
#     312     modules = OrderedDict([(str(idx), module) for idx, module in enumerate(modules)])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sentence_transformers\SentenceTransformer.py:1324, in SentenceTransformer._load_auto_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    1321 tokenizer_kwargs = shared_kwargs if tokenizer_kwargs is None else {**shared_kwargs, **tokenizer_kwargs}
#    1322 config_kwargs = shared_kwargs if config_kwargs is None else {**shared_kwargs, **config_kwargs}
# -> 1324 transformer_model = Transformer(
#    1325     model_name_or_path,
#    1326     cache_dir=cache_folder,
#    1327     model_args=model_kwargs,
#    1328     tokenizer_args=tokenizer_kwargs,
#    1329     config_args=config_kwargs,
#    1330 )
#    1331 pooling_model = Pooling(transformer_model.get_word_embedding_dimension(), "mean")
#    1332 self.model_card_data.set_base_model(model_name_or_path, revision=revision)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sentence_transformers\models\Transformer.py:54, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path)
#      51     config_args = {}
#      53 config = AutoConfig.from_pretrained(model_name_or_path, **config_args, cache_dir=cache_dir)
# ---> 54 self._load_model(model_name_or_path, config, cache_dir, **model_args)
#      56 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#      57     tokenizer_args["model_max_length"] = max_seq_length
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sentence_transformers\models\Transformer.py:85, in Transformer._load_model(self, model_name_or_path, config, cache_dir, **model_args)
#      83     self._load_mt5_model(model_name_or_path, config, cache_dir, **model_args)
#      84 else:
# ---> 85     self.auto_model = AutoModel.from_pretrained(
#      86         model_name_or_path, config=config, cache_dir=cache_dir, **model_args
#      87     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\models\auto\auto_factory.py:564, in _BaseAutoModelClass.from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     562 elif type(config) in cls._model_mapping.keys():
#     563     model_class = _get_model_class(config, cls._model_mapping)
# --> 564     return model_class.from_pretrained(
#     565         pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     566     )
#     567 raise ValueError(
#     568     f"Unrecognized configuration class {config.__class__} for this kind of AutoModel: {cls.__name__}.\n"
#     569     f"Model type should be one of {', '.join(c.__name__ for c in cls._model_mapping.keys())}."
#     570 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\modeling_utils.py:3715, in PreTrainedModel.from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    3712 # We'll need to download and cache each checkpoint shard if the checkpoint is sharded.
#    3713 if is_sharded:
#    3714     # resolved_archive_file becomes a list of files that point to the different checkpoint shards in this case.
# -> 3715     resolved_archive_file, sharded_metadata = get_checkpoint_shard_files(
#    3716         pretrained_model_name_or_path,
#    3717         resolved_archive_file,
#    3718         cache_dir=cache_dir,
#    3719         force_download=force_download,
#    3720         proxies=proxies,
#    3721         resume_download=resume_download,
#    3722         local_files_only=local_files_only,
#    3723         token=token,
#    3724         user_agent=user_agent,
#    3725         revision=revision,
#    3726         subfolder=subfolder,
#    3727         _commit_hash=commit_hash,
#    3728     )
#    3730 if (
#    3731     is_safetensors_available()
#    3732     and isinstance(resolved_archive_file, str)
#    3733     and resolved_archive_file.endswith(".safetensors")
#    3734 ):
#    3735     with safe_open(resolved_archive_file, framework="pt") as f:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\utils\hub.py:1079, in get_checkpoint_shard_files(pretrained_model_name_or_path, index_filename, cache_dir, force_download, proxies, resume_download, local_files_only, token, user_agent, revision, subfolder, _commit_hash, **deprecated_kwargs)
#    1076 for shard_filename in tqdm(shard_filenames, desc="Downloading shards", disable=not show_progress_bar):
#    1077     try:
#    1078         # Load from URL
# -> 1079         cached_filename = cached_file(
#    1080             pretrained_model_name_or_path,
#    1081             shard_filename,
#    1082             cache_dir=cache_dir,
#    1083             force_download=force_download,
#    1084             proxies=proxies,
#    1085             resume_download=resume_download,
#    1086             local_files_only=local_files_only,
#    1087             token=token,
#    1088             user_agent=user_agent,
#    1089             revision=revision,
#    1090             subfolder=subfolder,
#    1091             _commit_hash=_commit_hash,
#    1092         )
#    1093     # We have already dealt with RepositoryNotFoundError and RevisionNotFoundError when getting the index, so
#    1094     # we don't have to catch them here.
#    1095     except EntryNotFoundError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\transformers\utils\hub.py:402, in cached_file(path_or_repo_id, filename, cache_dir, force_download, resume_download, proxies, token, revision, local_files_only, subfolder, repo_type, user_agent, _raise_exceptions_for_gated_repo, _raise_exceptions_for_missing_entries, _raise_exceptions_for_connection_errors, _commit_hash, **deprecated_kwargs)
#     399 user_agent = http_user_agent(user_agent)
#     400 try:
#     401     # Load from URL or cache if already cached
# --> 402     resolved_file = hf_hub_download(
#     403         path_or_repo_id,
#     404         filename,
#     405         subfolder=None if len(subfolder) == 0 else subfolder,
#     406         repo_type=repo_type,
#     407         revision=revision,
#     408         cache_dir=cache_dir,
#     409         user_agent=user_agent,
#     410         force_download=force_download,
#     411         proxies=proxies,
#     412         resume_download=resume_download,
#     413         token=token,
#     414         local_files_only=local_files_only,
#     415     )
#     416 except GatedRepoError as e:
#     417     resolved_file = _get_cache_file_to_return(path_or_repo_id, full_filename, cache_dir, revision)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\utils\_validators.py:114, in validate_hf_hub_args.<locals>._inner_fn(*args, **kwargs)
#     111 if check_use_auth_token:
#     112     kwargs = smoothly_deprecate_use_auth_token(fn_name=fn.__name__, has_token=has_token, kwargs=kwargs)
# --> 114 return fn(*args, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:1221, in hf_hub_download(repo_id, filename, subfolder, repo_type, revision, library_name, library_version, cache_dir, local_dir, user_agent, force_download, proxies, etag_timeout, token, local_files_only, headers, endpoint, legacy_cache_layout, resume_download, force_filename, local_dir_use_symlinks)
#    1202     return _hf_hub_download_to_local_dir(
#    1203         # Destination
#    1204         local_dir=local_dir,
#    (...)
#    1218         local_files_only=local_files_only,
#    1219     )
#    1220 else:
# -> 1221     return _hf_hub_download_to_cache_dir(
#    1222         # Destination
#    1223         cache_dir=cache_dir,
#    1224         # File info
#    1225         repo_id=repo_id,
#    1226         filename=filename,
#    1227         repo_type=repo_type,
#    1228         revision=revision,
#    1229         # HTTP info
#    1230         headers=headers,
#    1231         proxies=proxies,
#    1232         etag_timeout=etag_timeout,
#    1233         endpoint=endpoint,
#    1234         # Additional options
#    1235         local_files_only=local_files_only,
#    1236         force_download=force_download,
#    1237     )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:1367, in _hf_hub_download_to_cache_dir(cache_dir, repo_id, filename, repo_type, revision, headers, proxies, etag_timeout, endpoint, local_files_only, force_download)
#    1365 Path(lock_path).parent.mkdir(parents=True, exist_ok=True)
#    1366 with WeakFileLock(lock_path):
# -> 1367     _download_to_tmp_and_move(
#    1368         incomplete_path=Path(blob_path + ".incomplete"),
#    1369         destination_path=Path(blob_path),
#    1370         url_to_download=url_to_download,
#    1371         proxies=proxies,
#    1372         headers=headers,
#    1373         expected_size=expected_size,
#    1374         filename=filename,
#    1375         force_download=force_download,
#    1376     )
#    1377     _create_symlink(blob_path, pointer_path, new_blob=True)
#    1379 return pointer_path
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:1884, in _download_to_tmp_and_move(incomplete_path, destination_path, url_to_download, proxies, headers, expected_size, filename, force_download)
#    1881         _check_disk_space(expected_size, incomplete_path.parent)
#    1882         _check_disk_space(expected_size, destination_path.parent)
# -> 1884     http_get(
#    1885         url_to_download,
#    1886         f,
#    1887         proxies=proxies,
#    1888         resume_size=resume_size,
#    1889         headers=headers,
#    1890         expected_size=expected_size,
#    1891     )
#    1893 logger.info(f"Download complete. Moving file to {destination_path}")
#    1894 _chmod_and_move(incomplete_path, destination_path)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\huggingface_hub\file_download.py:539, in http_get(url, temp_file, proxies, resume_size, headers, expected_size, displayed_filename, _nb_retries, _tqdm_bar)
#     537 new_resume_size = resume_size
#     538 try:
# --> 539     for chunk in r.iter_content(chunk_size=DOWNLOAD_CHUNK_SIZE):
#     540         if chunk:  # filter out keep-alive new chunks
#     541             progress.update(len(chunk))
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:628, in HTTPResponse.stream(self, amt, decode_content)
#     626 else:
#     627     while not is_fp_closed(self._fp):
# --> 628         data = self.read(amt=amt, decode_content=decode_content)
#     630         if data:
#     631             yield data
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:567, in HTTPResponse.read(self, amt, decode_content, cache_content)
#     564 fp_closed = getattr(self._fp, "closed", False)
#     566 with self._error_catcher():
# --> 567     data = self._fp_read(amt) if not fp_closed else b""
#     568     if amt is None:
#     569         flush_decoder = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\urllib3\response.py:533, in HTTPResponse._fp_read(self, amt)
#     530     return buffer.getvalue()
#     531 else:
#     532     # StringIO doesn't like amt=None
# --> 533     return self._fp.read(amt) if amt is not None else self._fp.read()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:473, in HTTPResponse.read(self, amt)
#     470 if self.length is not None and amt > self.length:
#     471     # clip the read to the "end of response"
#     472     amt = self.length
# --> 473 s = self.fp.read(amt)
#     474 if not s and amt:
#     475     # Ideally, we would raise IncompleteRead if the content-length
#     476     # wasn't satisfied, but it might break compatibility.
#     477     self._close_conn()
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.11_3.11.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
index = VectorStoreIndex.from_documents(
    documents, storage_context=storage_context
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\llama_index\core\embeddings\utils.py:59, in resolve_embed_model(embed_model, callback_manager)
#      58     embed_model = OpenAIEmbedding()
# ---> 59     validate_openai_api_key(embed_model.api_key)
#      60 except ImportError:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\llama_index\embeddings\openai\utils.py:103, in validate_openai_api_key(api_key)
#     102 if not openai_api_key:
# --> 103     raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 index = VectorStoreIndex.from_documents(
#       2     documents, storage_context=storage_context
#       3 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\llama_index\core\indices\base.py:119, in BaseIndex.from_documents(cls, documents, storage_context, show_progress, callback_manager, transformations, **kwargs)
#     110     docstore.set_document_hash(doc.get_doc_id(), doc.hash)
#     112 nodes = run_transformations(
#     113     documents,  # type: ignore
#     114     transformations,
#     115     show_progress=show_progress,
#     116     **kwargs,
#     117 )
# --> 119 return cls(
#     120     nodes=nodes,
#     121     storage_context=storage_context,
#     122     callback_manager=callback_manager,
#     123     show_progress=show_progress,
#     124     transformations=transformations,
#     125     **kwargs,
#     126 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\llama_index\core\indices\vector_store\base.py:71, in VectorStoreIndex.__init__(self, nodes, use_async, store_nodes_override, embed_model, insert_batch_size, objects, index_struct, storage_context, callback_manager, transformations, show_progress, **kwargs)
#      66 self._use_async = use_async
#      67 self._store_nodes_override = store_nodes_override
#      68 self._embed_model = (
#      69     resolve_embed_model(embed_model, callback_manager=callback_manager)
#      70     if embed_model
# ---> 71     else Settings.embed_model
#      72 )
#      74 self._insert_batch_size = insert_batch_size
#      75 super().__init__(
#      76     nodes=nodes,
#      77     index_struct=index_struct,
#    (...)
#      83     **kwargs,
#      84 )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\llama_index\core\settings.py:64, in _Settings.embed_model(self)
#      62 """Get the embedding model."""
#      63 if self._embed_model is None:
# ---> 64     self._embed_model = resolve_embed_model("default")
#      66 if self._callback_manager is not None:
#      67     self._embed_model.callback_manager = self._callback_manager
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\llama_index\core\embeddings\utils.py:66, in resolve_embed_model(embed_model, callback_manager)
#      61         raise ImportError(
#      62             "`llama-index-embeddings-openai` package not found, "
#      63             "please run `pip install llama-index-embeddings-openai`"
#      64         )
#      65     except ValueError as e:
# ---> 66         raise ValueError(
#      67             "\n******\n"
#      68             "Could not load OpenAI embedding model. "
#      69             "If you intended to use OpenAI, please check your OPENAI_API_KEY.\n"
#      70             "Original error:\n"
#      71             f"{e!s}"
#      72             "\nConsider using embed_model='local'.\n"
#      73             "Visit our documentation for more embedding options: "
#      74             "https://docs.llamaindex.ai/en/stable/module_guides/models/"
#      75             "embeddings.html#modules"
#      76             "\n******"
#      77         )
#      78 # for image multi-modal embeddings
#      79 elif isinstance(embed_model, str) and embed_model.startswith("clip"):
#
# ValueError:
# ******
# Could not load OpenAI embedding model. If you intended to use OpenAI, please check your OPENAI_API_KEY.
# Original error:
# No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
# Consider using embed_model='local'.
# Visit our documentation for more embedding options: https://docs.llamaindex.ai/en/stable/module_guides/models/embeddings.html#modules
# ******
